# %% [markdown]
# <a href="https://colab.research.google.com/github/vedika01105/4_VEDIKA_SISODIYA_D2/blob/main/Univariate_analysis/Univariate_analysis_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("heart.csv")

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %% [markdown]
# # 1. Categorial Data

# %% [markdown]
# ## a. Countplot

# %%
sns.countplot(x=df['target'])
# df['Survived'].value_counts().plot(kind = 'bar')

# %% [markdown]
# ## b. Piechart

# %%
df['sex'].value_counts().plot(kind = 'pie', autopct = '%.2f')

# %% [markdown]
# # 2. Numerical Data

# %% [markdown]
# ## a. Histogram

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(df['age'], bins=5)

# %% [markdown]
# ## b. Distplot

# %%
sns.distplot(df['age'])

# %% [markdown]
# ## c. Boxplot

# %%
sns.boxplot(df['age'])
# Out:
# <Axes: ylabel='age'>

# %%
df['age'].min()
# Out:
# 29

# %%
df['age'].mean()
# Out:
# np.float64(54.43414634146342)
