# %% [markdown]
# <a href="https://colab.research.google.com/github/vedika01105/4_VEDIKA_SISODIYA_D2/blob/main/working_with_CSV_files.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importing Pandas

# %%
import pandas as pd

# %% [markdown]
# ## Opening a local CSV file

# %%
df = pd.read_csv("/content/aug_train.csv")
df

# %% [markdown]
# ## Opening a CSV file from URL

# %%
import requests
from io import StringIO

url = "https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv"
# headers = {"User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; rv:66.0) Gecko/20100101 Firefox/66.0"}
req = requests.get(url)
data = StringIO(req.text)

pd. read_csv(data)

# %% [markdown]
# ## Sep Parameter

# %%
pd.read_csv("/content/movie_titles_metadata.tsv", sep="\t", names=['sno', 'name','release_year','rating','votes','genres'])

# %% [markdown]
# ## Index_col Parameter
# makes the given column as index column

# %%
pd.read_csv("/content/aug_train.csv", index_col="enrollee_id")

# %% [markdown]
# ## Header Parameter
# makes the given row as column names

# %%
pd.read_csv("/content/test.csv",header=1)

# %% [markdown]
# ## use_cols Parameter

# %%
pd.read_csv("/content/aug_train.csv", usecols=['enrollee_id','gender','education_level'])

# %% [markdown]
# ## Squeez Parameter
# converts 2D data to 1D
# but it's depricated (no more available)

# %%
# pd.read_csv("/aug_train.csv",usecols='gender',squeeze=True)

# %% [markdown]
# ## Skiprows/nrows Parameter
# skipsrows skips the given rowns
# nrows give n number of rows

# %%
pd.read_csv("/content/aug_train.csv",nrows=100)

# %% [markdown]
# ## Encoding Parameter

# %%
pd.read_csv("/content/zomato.csv",encoding= 'latin-1')

# %% [markdown]
# ## Skip bad lines

# %%
# pd.read_csv('BX-Books.csv', sep=';', encoding="latin-1",error_bad_lines=False)

# %% [markdown]
# ## dtypes Parameter

# %%
pd.read_csv("/content/aug_train.csv",dtype={'target' : int}).info()

# %% [markdown]
# ### Handling Dates

# %%
pd.read_csv("/content/IPL Matches 2008-2020.csv",parse_dates=['date']).info()

# %%
def rename(name):
  if name == "Royal Challengers Bangalore":
    return "RCB"
  else:
    return name

# %%
rename("Royal Challengers Bangalore")
# Out:
# 'RCB'

# %% [markdown]
# ## Convertors

# %%
pd.read_csv("/content/IPL Matches 2008-2020.csv",converters={'team1':rename})

# %% [markdown]
# ## na_values parameter

# %%
pd.read_csv("/content/aug_train.csv",na_values=['Male',])

# %% [markdown]
# ## Loading a huge dataset in chunks

# %%
dfs = pd.read_csv("/content/aug_train.csv",chunksize=5000)

# %%
for chunk in dfs:
  print(chunk)
