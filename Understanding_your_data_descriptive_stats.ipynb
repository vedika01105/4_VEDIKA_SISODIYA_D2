# %% [markdown]
# <a href="https://colab.research.google.com/github/vedika01105/4_VEDIKA_SISODIYA_D2/blob/main/Understanding_your_data_descriptive_stats.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/train.csv")

# %% [markdown]
# ## How big is the data?

# %%
df.shape
# Out:
# (891, 12)

# %% [markdown]
# ## How does the data look like?

# %%
df.sample(5)

# %% [markdown]
# ## What is the data type of cols?

# %%
df.info()

# %% [markdown]
# ## Are there any missing values

# %%
df.isnull().sum()

# %% [markdown]
# ## How does the data look mathematically?

# %%
df.describe()

# %% [markdown]
# ## Are there any duplicate values?

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## How is the correlation between cols?

# %%
df.corr()['survived']
